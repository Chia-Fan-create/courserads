# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
x = [1,2,3,4,5,6,7,8,9]
y = [3,6,2,8,11,12,16,14,12]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
import numpy as np
bins = np.linspace(min(y), max(y), 4)
bins
# Out:
# array([ 2.        ,  6.66666667, 11.33333333, 16.        ])

# %%
plt.hist(x,bins)
# Out:
# (array([5., 3., 0.]),
#  array([ 2.        ,  6.66666667, 11.33333333, 16.        ]),
#  <BarContainer object of 3 artists>)
