# %%
# !pip install numpy==2.2.0
# !pip install pandas==2.2.3
# !pip install scikit-learn==1.6.0
# !pip install matplotlib==3.9.3
# !pip install seaborn==0.13.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Ignored the following versions that require a different python version: 2.1.0 Requires-Python >=3.10; 2.1.1 Requires-Python >=3.10; 2.1.2 Requires-Python >=3.10; 2.1.3 Requires-Python >=3.10; 2.2.0 Requires-Python >=3.10; 2.2.1 Requires-Python >=3.10; 2.2.2 Requires-Python >=3.10; 2.2.3 Requires-Python >=3.10; 2.2.4 Requires-Python >=3.10; 2.2.5 Requires-Python >=3.10; 2.2.6 Requires-Python >=3.10; 2.3.0 Requires-Python >=3.11; 2.3.1 Requires-Python >=3.11; 2.3.2 Requires-Python >=3.11; 2.3.3 Requires-Python >=3.11; 2.3.4 Requires-Python >=3.11; 2.3.5 Requires-Python >=3.11; 2.4.0 Requires-Python >=3.11; 2.4.0rc1 Requires-Python >=3.11; 2.4.1 Requires-Python >=3.11; 2.4.2 Requires-Python >=3.11; 2.4.3 Requires-Python >=3.11
# ERROR: Could not find a version that satisfies the requirement numpy==2.2.0 (from versions: 1.3.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0.post2, 1.10.1, 1.10.2, 1.10.4, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 1.13.3, 1.14.0, 1.14.1, 1.14.2, 1.14.3, 1.14.4, 1.14.5, 1.14.6, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.15.4, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.19.0, 1.19.1, 1.19.2, 1.19.3, 1.19.4, 1.19.5, 1.20.0, 1.20.1, 1.20.2, 1.20.3, 1.21.0, 1.21.1, 1.21.2, 1.21.3, 1.21.4, 1.21.5, 1.21.6, 1.22.0, 1.22.1, 1.22.2, 1.22.3, 1.22.4, 1.23.0, 1.23.1, 1.23.2, 1.23.3, 1.23.4, 1.23.5, 1.24.0, 1.24.1, 1.24.2, 1.24.3, 1.24.4, 1.25.0, 1.25.1, 1.25.2, 1.26.0, 1.26.1, 1.26.2, 1.26.3, 1.26.4, 2.0.0, 2.0.1, 2.0.2)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# ERROR: No matching distribution found for numpy==2.2.0
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas==2.2.3 in /Users/fran/Library/Python/3.9/lib/python/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from pandas==2.2.3) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn==1.6.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from scikit-learn==1.6.0) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from scikit-learn==1.6.0) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from scikit-learn==1.6.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from scikit-learn==1.6.0) (3.6.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib==3.9.3 in /Users/fran/Library/Python/3.9/lib/python/site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib==3.9.3) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib==3.9.3) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn==0.13.2 in /Users/fran/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from seaborn==0.13.2) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from seaborn==0.13.2) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from seaborn==0.13.2) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn==0.13.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn==0.13.2) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/fran/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
# %matplotlib inline

# %%
df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%203/data/teleCust1000t.csv')
df.head()
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
df['custcat'].value_counts()
# Out:
# custcat
# 3    281
# 1    266
# 4    236
# 2    217
# Name: count, dtype: int64

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
# Out:
# <Axes: >

# %%
correlation_values = abs(df.corr()['custcat'].drop('custcat')).sort_values(ascending=False)
correlation_values
# Out:
# ed         0.193864
# tenure     0.166691
# income     0.134525
# employ     0.110011
# marital    0.083836
# reside     0.082022
# address    0.067913
# age        0.056909
# region     0.023771
# retire     0.008908
# gender     0.004966
# Name: custcat, dtype: float64

# %%
X = df.drop('custcat',axis=1)
y = df['custcat']

# %%
X_norm = StandardScaler().fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.2, random_state=4)

# %% [markdown]
# ### KNN Classification

# %%
k = 3
#Train Model and Predict  
knn_classifier = KNeighborsClassifier(n_neighbors=k)
knn_model = knn_classifier.fit(X_train,y_train)

# %%
yhat = knn_model.predict(X_test)

# %%
print("Test set Accuracy: ", accuracy_score(y_test, yhat))
# Out:
# Test set Accuracy:  0.315

# %%
k = 6
knn_model_6 = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
yhat6 = knn_model_6.predict(X_test)
print("Test set Accuracy: ", accuracy_score(y_test, yhat6))
# Out:
# Test set Accuracy:  0.31

# %%
Ks = 10
acc = np.zeros((Ks))
std_acc = np.zeros((Ks))
for n in range(1,Ks+1):
    #Train Model and Predict  
    knn_model_n = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat = knn_model_n.predict(X_test)
    acc[n-1] = accuracy_score(y_test, yhat)
    std_acc[n-1] = np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

# %%
plt.plot(range(1,Ks+1),acc,'g')
plt.fill_between(range(1,Ks+1),acc - 1 * std_acc,acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy value', 'Standard Deviation'))
plt.ylabel('Model Accuracy')
plt.xlabel('Number of Neighbors (K)')
plt.tight_layout()
plt.show()

# %%
print( "The best accuracy was with", acc.max(), "with k =", acc.argmax()+1)
# Out:
# The best accuracy was with 0.34 with k = 9

# %%
# Run the training model for 30 values of k and then again for 100 values of k. Identify the value of k that best suits this data and the accuracy on the test set for this model.
Ks = 30
acc = np.zeros((Ks))
for n in range(1,Ks+1):
    #Train Model and Predict  
    knn_model_n = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat = knn_model_n.predict(X_test)
    acc[n-1] = accuracy_score(y_test, yhat)
plt.plot(range(1,Ks+1),acc,'g')
plt.ylabel('Model Accuracy')
plt.xlabel('Number of Neighbors (K)')
plt.tight_layout()
plt.show()

# %%
# Plot the variation of the accuracy score for the training set for 100 value of Ks.
Ks = 100
acc = np.zeros((Ks))
for n in range(1,Ks+1):     
    knn_model_n = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat = knn_model_n.predict(X_test)
    acc[n-1] = accuracy_score(y_test, yhat)
plt.plot(range(1,Ks+1),acc,'g')
plt.ylabel('Model Accuracy')
plt.xlabel('Number of Neighbors (K)')
plt.tight_layout()
plt.show()

# %%
# Can you justify why the model performance on training data is deteriorating with increase in the value of k?

# When k is small (e.g., k=1), the model is highly sensitive to the individual points in the dataset. The prediction for each point is based on its closest neighbor, which can lead to highly specific and flexible boundaries. This leads to overfitting on the training data, meaning the model will perform very well on the training set, potentially achieving 100% accuracy. However, it may generalize poorly to unseen data. When k is large, the model starts to take into account more neighbors when making predictions. This has two main consequences:

# Smoothing of the Decision Boundary: The decision boundary becomes smoother, which means the model is less sensitive to the noise or fluctuations in the training data.
# Less Specific Predictions: With a larger k, the model considers more neighbors and therefore makes more generalized predictions, which can lead to fewer instances being classified perfectly.
# As a result, the model starts to become less flexible, and its ability to memorize the training data (which can lead to perfect accuracy with small k) is reduced.


# We can see that even the with the optimum values, the KNN model is not performing that well on the given data set. Can you think of the possible reasons for this?

# he weak performance on the model can be due to multiple reasons. 
# 1. The KNN model relies entirely on the raw feature space at inference time. If the features do no provide clear boundaries between classes, KNN model cannot compensate through optimization or feature transformation. 
# 2. For a high number of weakly correlated features, the number of dimensions increases, the distance between points tend to become more uniform, reducing the discriminative power of KNN. 3. The algorithm treats all features equally when computing distances. Hence, weakly correalted features can introduce noise or irrelevant variations in the feature space making it harder for KNN to find meaningful neighbours.
